# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import datetime as dt
import matplotlib
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import seaborn as sns
from math import floor, ceil
from pylab import rcParams

# %%
# Training Data Paths
burn = pd.read_csv("burntrain.csv")
burn2 = pd.read_csv("burntest.csv")
burn.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe32003000360033003200      2008-09-30  Female      Service
# 1      fffe3700360033003500      2008-11-30    Male      Service
# 2  fffe31003300320037003900      2008-03-10  Female      Product
# 3  fffe32003400380032003900      2008-11-03    Male      Service
# 4  fffe31003900340031003600      2008-07-24  Female      Service
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score  \
# 0                  No          2.0                  3.0                   3.8
# 1                 Yes          1.0                  2.0                   5.0
# 2                 Yes          2.0                  NaN                   5.8
# 3                 Yes          1.0                  1.0                   2.6
# 4                  No          3.0                  7.0                   6.9
#
#    Burn Rate
# 0       0.16
# 1       0.36
# 2       0.49
# 3       0.20
# 4       0.52

# %%
burn2.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe31003300390039003000      2008-12-10  Female      Service
# 1  fffe31003300310037003800      2008-08-14  Female      Product
# 2  fffe33003400380035003900      2008-11-13    Male      Product
# 3      fffe3100370039003200      2008-02-07  Female      Service
# 4  fffe32003600390036003700      2008-07-17  Female      Product
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score
# 0                  No          2.0                  5.0                   7.7
# 1                 Yes          1.0                  2.0                   5.2
# 2                 Yes          1.0                  3.0                   5.9
# 3                  No          3.0                  6.0                   4.6
# 4                  No          2.0                  5.0                   6.4

# %%
del burn['Employee ID']
del burn2['Employee ID']

# %%
burn = burn.replace(np.nan, 0)
burn2 = burn2.replace(np.nan, 0)
burn.head(5)
# Out:
#   Date of Joining  Gender Company Type WFH Setup Available  Designation  \
# 0      2008-09-30  Female      Service                  No          2.0
# 1      2008-11-30    Male      Service                 Yes          1.0
# 2      2008-03-10  Female      Product                 Yes          2.0
# 3      2008-11-03    Male      Service                 Yes          1.0
# 4      2008-07-24  Female      Service                  No          3.0
#
#    Resource Allocation  Mental Fatigue Score  Burn Rate
# 0                  3.0                   3.8       0.16
# 1                  2.0                   5.0       0.36
# 2                  0.0                   5.8       0.49
# 3                  1.0                   2.6       0.20
# 4                  7.0                   6.9       0.52

# %%
burn.loc[burn['Burn Rate'] == 1.0]
# Out:
#       Date of Joining  Gender Company Type WFH Setup Available  Designation  \
# 426        2008-09-06  Female      Service                  No          5.0
# 621        2008-03-27  Female      Product                 Yes          5.0
# 729        2008-05-31  Female      Service                  No          4.0
# 878        2008-07-02  Female      Product                 Yes          4.0
# 1241       2008-09-24    Male      Service                  No          5.0
# ...               ...     ...          ...                 ...          ...
# 21391      2008-09-25  Female      Product                  No          5.0
# 21580      2008-05-19  Female      Service                  No          5.0
# 22307      2008-05-17    Male      Service                  No          5.0
# 22596      2008-03-20    Male      Product                 Yes          5.0
# 22623      2008-12-25    Male      Service                  No          5.0
#
#        Resource Allocation  Mental Fatigue Score  Burn Rate
# 426                   10.0                   0.0        1.0
# 621                    0.0                   9.4        1.0
# 729                    9.0                   9.3        1.0
# 878                    8.0                   0.0        1.0
# 1241                  10.0                   9.4        1.0
# ...                    ...                   ...        ...
# 21391                 10.0                   9.2        1.0
# 21580                 10.0                   9.9        1.0
# 22307                  9.0                   0.0        1.0
# 22596                 10.0                   0.0        1.0
# 22623                 10.0                  10.0        1.0
#
# [85 rows x 8 columns]

# %%
burn['Date of Joining'] =  pd.to_datetime(burn["Date of Joining"])
burn2['Date of Joining'] =  pd.to_datetime(burn2["Date of Joining"])
burn.head()
# Out:
#   Date of Joining  Gender Company Type WFH Setup Available  Designation  \
# 0      2008-09-30  Female      Service                  No          2.0
# 1      2008-11-30    Male      Service                 Yes          1.0
# 2      2008-03-10  Female      Product                 Yes          2.0
# 3      2008-11-03    Male      Service                 Yes          1.0
# 4      2008-07-24  Female      Service                  No          3.0
#
#    Resource Allocation  Mental Fatigue Score  Burn Rate
# 0                  3.0                   3.8       0.16
# 1                  2.0                   5.0       0.36
# 2                  0.0                   5.8       0.49
# 3                  1.0                   2.6       0.20
# 4                  7.0                   6.9       0.52

# %%
burn2.head()
# Out:
#   Date of Joining  Gender Company Type WFH Setup Available  Designation  \
# 0      2008-12-10  Female      Service                  No          2.0
# 1      2008-08-14  Female      Product                 Yes          1.0
# 2      2008-11-13    Male      Product                 Yes          1.0
# 3      2008-02-07  Female      Service                  No          3.0
# 4      2008-07-17  Female      Product                  No          2.0
#
#    Resource Allocation  Mental Fatigue Score
# 0                  5.0                   7.7
# 1                  2.0                   5.2
# 2                  3.0                   5.9
# 3                  6.0                   4.6
# 4                  5.0                   6.4

# %%
burn['Date of Joining'] = pd.DatetimeIndex(burn['Date of Joining']).month
burn.rename(columns = {'Date of Joining' : 'Month Joined'}, inplace = True)
burn2['Date of Joining'] = pd.DatetimeIndex(burn2['Date of Joining']).month
burn2.rename(columns = {'Date of Joining' : 'Month Joined'}, inplace = True)
burn.head(10)
# Out:
#    Month Joined  Gender Company Type WFH Setup Available  Designation  \
# 0             9  Female      Service                  No          2.0
# 1            11    Male      Service                 Yes          1.0
# 2             3  Female      Product                 Yes          2.0
# 3            11    Male      Service                 Yes          1.0
# 4             7  Female      Service                  No          3.0
# 5            11    Male      Product                 Yes          2.0
# 6             1  Female      Service                  No          3.0
# 7            10  Female      Service                 Yes          2.0
# 8            12  Female      Service                  No          3.0
# 9             3  Female      Product                  No          3.0
#
#    Resource Allocation  Mental Fatigue Score  Burn Rate
# 0                  3.0                   3.8       0.16
# 1                  2.0                   5.0       0.36
# 2                  0.0                   5.8       0.49
# 3                  1.0                   2.6       0.20
# 4                  7.0                   6.9       0.52
# 5                  4.0                   3.6       0.29
# 6                  6.0                   7.9       0.62
# 7                  4.0                   4.4       0.33
# 8                  6.0                   0.0       0.56
# 9                  6.0                   0.0       0.67

# %%
burn_df_clean = {"Gender": {"Male": 0, "Female": 1},
                  "Company Type": {"Service" : 0, "Product" : 1},
                    "WFH Setup Available": {"No" : 0, "Yes": 1}}
burn_new_train = burn.replace(burn_df_clean)
burn_new_test = burn2.replace(burn_df_clean)
burn_new_train.head()
# Out:
#    Month Joined  Gender  Company Type  WFH Setup Available  Designation  \
# 0             9       1             0                    0          2.0
# 1            11       0             0                    1          1.0
# 2             3       1             1                    1          2.0
# 3            11       0             0                    1          1.0
# 4             7       1             0                    0          3.0
#
#    Resource Allocation  Mental Fatigue Score  Burn Rate
# 0                  3.0                   3.8       0.16
# 1                  2.0                   5.0       0.36
# 2                  0.0                   5.8       0.49
# 3                  1.0                   2.6       0.20
# 4                  7.0                   6.9       0.52

# %%
burn_new_test.head()
# Out:
#    Month Joined  Gender  Company Type  WFH Setup Available  Designation  \
# 0            12       1             0                    0          2.0
# 1             8       1             1                    1          1.0
# 2            11       0             1                    1          1.0
# 3             2       1             0                    0          3.0
# 4             7       1             1                    0          2.0
#
#    Resource Allocation  Mental Fatigue Score
# 0                  5.0                   7.7
# 1                  2.0                   5.2
# 2                  3.0                   5.9
# 3                  6.0                   4.6
# 4                  5.0                   6.4

# %%
features = pd.get_dummies(burn_new_train)
features.head(5)
# Out:
#    Month Joined  Gender  Company Type  WFH Setup Available  Designation  \
# 0             9       1             0                    0          2.0
# 1            11       0             0                    1          1.0
# 2             3       1             1                    1          2.0
# 3            11       0             0                    1          1.0
# 4             7       1             0                    0          3.0
#
#    Resource Allocation  Mental Fatigue Score  Burn Rate
# 0                  3.0                   3.8       0.16
# 1                  2.0                   5.0       0.36
# 2                  0.0                   5.8       0.49
# 3                  1.0                   2.6       0.20
# 4                  7.0                   6.9       0.52

# %%
features_test = pd.get_dummies(burn_new_test)
features_test.head()
# Out:
#    Month Joined  Gender  Company Type  WFH Setup Available  Designation  \
# 0            12       1             0                    0          2.0
# 1             8       1             1                    1          1.0
# 2            11       0             1                    1          1.0
# 3             2       1             0                    0          3.0
# 4             7       1             1                    0          2.0
#
#    Resource Allocation  Mental Fatigue Score
# 0                  5.0                   7.7
# 1                  2.0                   5.2
# 2                  3.0                   5.9
# 3                  6.0                   4.6
# 4                  5.0                   6.4

# %%
features["Burn Rate"].max()
# Out:
# 1.0

# %%
features.rename(columns = {'Burn Rate' : 'Burn_Rate'}, inplace = True)

# %%
features['Burn_Rate'] = features['Burn_Rate'].round(decimals=1)
features.head()
# Out:
#    Month Joined  Gender  Company Type  WFH Setup Available  Designation  \
# 0             9       1             0                    0          2.0
# 1            11       0             0                    1          1.0
# 2             3       1             1                    1          2.0
# 3            11       0             0                    1          1.0
# 4             7       1             0                    0          3.0
#
#    Resource Allocation  Mental Fatigue Score  Burn_Rate
# 0                  3.0                   3.8        0.2
# 1                  2.0                   5.0        0.4
# 2                  0.0                   5.8        0.5
# 3                  1.0                   2.6        0.2
# 4                  7.0                   6.9        0.5

# %%
features_test["Burn_Rate"] = 0
features_test
# Out:
#        Month Joined  Gender  Company Type  WFH Setup Available  Designation  \
# 0                12       1             0                    0          2.0
# 1                 8       1             1                    1          1.0
# 2                11       0             1                    1          1.0
# 3                 2       1             0                    0          3.0
# 4                 7       1             1                    0          2.0
# ...             ...     ...           ...                  ...          ...
# 12245            10       1             0                    1          1.0
# 12246             3       1             1                    1          2.0
# 12247             2       0             0                    0          4.0
# 12248             2       0             0                    0          3.0
# 12249             8       1             1                    0          2.0
#
#        Resource Allocation  Mental Fatigue Score  Burn_Rate
# 0                      5.0                   7.7          0
# 1                      2.0                   5.2          0
# 2                      3.0                   5.9          0
# 3                      6.0                   4.6          0
# 4                      5.0                   6.4          0
# ...                    ...                   ...        ...
# 12245                  2.0                   6.1          0
# 12246                  4.0                   5.9          0
# 12247                  7.0                   9.6          0
# 12248                  6.0                   6.7          0
# 12249                  2.0                   2.0          0
#
# [12250 rows x 8 columns]

# %%
features.Burn_Rate.value_counts().plot(kind="bar", rot=0)

# %%
# A general correlations matrix
corr_mat = features.corr() 
fig, ax = plt.subplots(figsize=(20, 12)) 
sns.heatmap(corr_mat, vmax=1.0, square=True, ax=ax);

# %%
corr_mat = features_test.corr() 
fig, ax = plt.subplots(figsize=(20, 12)) 
sns.heatmap(corr_mat, vmax=1.0, square=True, ax=ax);

# %%
features.columns = features.columns.str.replace(' ', '_')
features.head()
# Out:
#    Month_Joined  Gender  Company_Type  WFH_Setup_Available  Designation  \
# 0             9       1             0                    0          2.0
# 1            11       0             0                    1          1.0
# 2             3       1             1                    1          2.0
# 3            11       0             0                    1          1.0
# 4             7       1             0                    0          3.0
#
#    Resource_Allocation  Mental_Fatigue_Score  Burn_Rate
# 0                  3.0                   3.8        0.2
# 1                  2.0                   5.0        0.4
# 2                  0.0                   5.8        0.5
# 3                  1.0                   2.6        0.2
# 4                  7.0                   6.9        0.5

# %%
features_test.head()
# Out:
#    Month Joined  Gender  Company Type  WFH Setup Available  Designation  \
# 0            12       1             0                    0          2.0
# 1             8       1             1                    1          1.0
# 2            11       0             1                    1          1.0
# 3             2       1             0                    0          3.0
# 4             7       1             1                    0          2.0
#
#    Resource Allocation  Mental Fatigue Score  Burn_Rate
# 0                  5.0                   7.7          0
# 1                  2.0                   5.2          0
# 2                  3.0                   5.9          0
# 3                  6.0                   4.6          0
# 4                  5.0                   6.4          0

# %%
X = features['Mental_Fatigue_Score'].values
Y = features['Burn_Rate'].values

# %%
plt.scatter(X, Y, c='red', label='Scatter Plot')
plt.xlabel('Gender')
plt.ylabel('An individuals burn rate')
plt.legend()
plt.show()

# %%
x_train = features[["Designation",  "Resource_Allocation"]].values
y_train = features["Burn_Rate"].values
x_test = features_test[["Designation",  "Resource Allocation"]].values
y_test = features_test["Burn_Rate"].values

# %%
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical
x_scaler = StandardScaler().fit(x_train)
x_train_scaled = x_scaler.transform(x_train)
x_test_scaled = x_scaler.transform(x_test)
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
from tensorflow.keras.models import Sequential

model = Sequential()

# %%
from tensorflow.keras.layers import Dense
number_inputs = 2
number_hidden_nodes = 4
model.add(Dense(units=number_hidden_nodes,
                activation='relu', input_dim=number_inputs))

# %%
number_classes = 2
model.add(Dense(units=number_classes, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 4)                 12
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 10
# =================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fit (train) the model
model.fit(
    x_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 711/711 - 1s - loss: 0.2936 - accuracy: 0.9107
# Epoch 2/100
# 711/711 - 0s - loss: 0.0528 - accuracy: 0.9931
# Epoch 3/100
# 711/711 - 0s - loss: 0.0379 - accuracy: 0.9931
# Epoch 4/100
# 711/711 - 0s - loss: 0.0308 - accuracy: 0.9931
# Epoch 5/100
# 711/711 - 0s - loss: 0.0271 - accuracy: 0.9931
# Epoch 6/100
# 711/711 - 1s - loss: 0.0255 - accuracy: 0.9931
# Epoch 7/100
# 711/711 - 0s - loss: 0.0247 - accuracy: 0.9931
# Epoch 8/100
# 711/711 - 0s - loss: 0.0240 - accuracy: 0.9931
# Epoch 9/100
# 711/711 - 0s - loss: 0.0236 - accuracy: 0.9931
# Epoch 10/100
# 711/711 - 1s - loss: 0.0234 - accuracy: 0.9931
# Epoch 11/100
# 711/711 - 1s - loss: 0.0232 - accuracy: 0.9931
# Epoch 12/100
# 711/711 - 1s - loss: 0.0231 - accuracy: 0.9931
# Epoch 13/100
# 711/711 - 1s - loss: 0.0230 - accuracy: 0.9931
# Epoch 14/100
# 711/711 - 1s - loss: 0.0229 - accuracy: 0.9931
# Epoch 15/100
# 711/711 - 1s - loss: 0.0228 - accuracy: 0.9931
# Epoch 16/100
# 711/711 - 1s - loss: 0.0226 - accuracy: 0.9931
# Epoch 17/100
# 711/711 - 1s - loss: 0.0226 - accuracy: 0.9931
# Epoch 18/100
# 711/711 - 1s - loss: 0.0224 - accuracy: 0.9931
# Epoch 19/100
# 711/711 - 1s - loss: 0.0223 - accuracy: 0.9931
# Epoch 20/100
# 711/711 - 1s - loss: 0.0224 - accuracy: 0.9931
# Epoch 21/100
# 711/711 - 1s - loss: 0.0221 - accuracy: 0.9931
# Epoch 22/100
# 711/711 - 1s - loss: 0.0221 - accuracy: 0.9931
# Epoch 23/100
# 711/711 - 1s - loss: 0.0221 - accuracy: 0.9931
# Epoch 24/100
# 711/711 - 1s - loss: 0.0220 - accuracy: 0.9931
# Epoch 25/100
# 711/711 - 1s - loss: 0.0219 - accuracy: 0.9931
# Epoch 26/100
# 711/711 - 1s - loss: 0.0219 - accuracy: 0.9931
# Epoch 27/100
# 711/711 - 1s - loss: 0.0218 - accuracy: 0.9931
# Epoch 28/100
# 711/711 - 1s - loss: 0.0217 - accuracy: 0.9931
# Epoch 29/100
# 711/711 - 1s - loss: 0.0217 - accuracy: 0.9931
# Epoch 30/100
# 711/711 - 0s - loss: 0.0216 - accuracy: 0.9930
# Epoch 31/100
# 711/711 - 0s - loss: 0.0216 - accuracy: 0.9931
# Epoch 32/100
# 711/711 - 0s - loss: 0.0215 - accuracy: 0.9931
# Epoch 33/100
# 711/711 - 0s - loss: 0.0216 - accuracy: 0.9930
# Epoch 34/100
# 711/711 - 0s - loss: 0.0214 - accuracy: 0.9930
# Epoch 35/100
# 711/711 - 0s - loss: 0.0214 - accuracy: 0.9930
# Epoch 36/100
# 711/711 - 0s - loss: 0.0213 - accuracy: 0.9931
# Epoch 37/100
# 711/711 - 0s - loss: 0.0213 - accuracy: 0.9930
# Epoch 38/100
# 711/711 - 0s - loss: 0.0214 - accuracy: 0.9931
# Epoch 39/100
# 711/711 - 0s - loss: 0.0213 - accuracy: 0.9929
# Epoch 40/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9932
# Epoch 41/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9931
# Epoch 42/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9931
# Epoch 43/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9930
# Epoch 44/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9930
# Epoch 45/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9930
# Epoch 46/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9928
# Epoch 47/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9930
# Epoch 48/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9932
# Epoch 49/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9931
# Epoch 50/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9932
# Epoch 51/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9932
# Epoch 52/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9928
# Epoch 53/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9932
# Epoch 54/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9927
# Epoch 55/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9928
# Epoch 56/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9931
# Epoch 57/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9930
# Epoch 58/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9932
# Epoch 59/100
# 711/711 - 1s - loss: 0.0211 - accuracy: 0.9931
# Epoch 60/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9931
# Epoch 61/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9931
# Epoch 62/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9929
# Epoch 63/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9930
# Epoch 64/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9927
# Epoch 65/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 66/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9929
# Epoch 67/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9929
# Epoch 68/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9930
# Epoch 69/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 70/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9930
# Epoch 71/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9932
# Epoch 72/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9928
# Epoch 73/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 74/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9928
# Epoch 75/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9928
# Epoch 76/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9928
# Epoch 77/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9931
# Epoch 78/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9927
# Epoch 79/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9930
# Epoch 80/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9929
# Epoch 81/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9932
# Epoch 82/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 83/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 84/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9929
# Epoch 85/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 86/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 87/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 88/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 89/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 90/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9930
# Epoch 91/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9930
# Epoch 92/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9927
# Epoch 93/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9929
# Epoch 94/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9927
# Epoch 95/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9928
# Epoch 96/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 97/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9927
# Epoch 98/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9929
# Epoch 99/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 100/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9932

# %%
#round 2
deep_model = Sequential()
deep_model.add(Dense(units=6, activation='relu', input_dim=2))
deep_model.add(Dense(units=6, activation='relu'))
deep_model.add(Dense(units=2, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 6)                 18
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 14
# =================================================================
# Total params: 74
# Trainable params: 74
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    x_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 711/711 - 1s - loss: 0.1369 - accuracy: 0.9916
# Epoch 2/100
# 711/711 - 1s - loss: 0.0337 - accuracy: 0.9931
# Epoch 3/100
# 711/711 - 1s - loss: 0.0283 - accuracy: 0.9931
# Epoch 4/100
# 711/711 - 1s - loss: 0.0261 - accuracy: 0.9931
# Epoch 5/100
# 711/711 - 1s - loss: 0.0247 - accuracy: 0.9931
# Epoch 6/100
# 711/711 - 1s - loss: 0.0239 - accuracy: 0.9931
# Epoch 7/100
# 711/711 - 1s - loss: 0.0231 - accuracy: 0.9931
# Epoch 8/100
# 711/711 - 1s - loss: 0.0224 - accuracy: 0.9931
# Epoch 9/100
# 711/711 - 1s - loss: 0.0220 - accuracy: 0.9931
# Epoch 10/100
# 711/711 - 1s - loss: 0.0216 - accuracy: 0.9931
# Epoch 11/100
# 711/711 - 0s - loss: 0.0215 - accuracy: 0.9931
# Epoch 12/100
# 711/711 - 1s - loss: 0.0213 - accuracy: 0.9931
# Epoch 13/100
# 711/711 - 0s - loss: 0.0213 - accuracy: 0.9931
# Epoch 14/100
# 711/711 - 1s - loss: 0.0213 - accuracy: 0.9931
# Epoch 15/100
# 711/711 - 1s - loss: 0.0212 - accuracy: 0.9931
# Epoch 16/100
# 711/711 - 1s - loss: 0.0211 - accuracy: 0.9931
# Epoch 17/100
# 711/711 - 1s - loss: 0.0211 - accuracy: 0.9931
# Epoch 18/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9931
# Epoch 19/100
# 711/711 - 1s - loss: 0.0211 - accuracy: 0.9931
# Epoch 20/100
# 711/711 - 1s - loss: 0.0211 - accuracy: 0.9931
# Epoch 21/100
# 711/711 - 1s - loss: 0.0211 - accuracy: 0.9931
# Epoch 22/100
# 711/711 - 1s - loss: 0.0211 - accuracy: 0.9931
# Epoch 23/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9931
# Epoch 24/100
# 711/711 - 1s - loss: 0.0212 - accuracy: 0.9931
# Epoch 25/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9931
# Epoch 26/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9931
# Epoch 27/100
# 711/711 - 1s - loss: 0.0211 - accuracy: 0.9931
# Epoch 28/100
# 711/711 - 1s - loss: 0.0212 - accuracy: 0.9931
# Epoch 29/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9931
# Epoch 30/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9931
# Epoch 31/100
# 711/711 - 1s - loss: 0.0211 - accuracy: 0.9931
# Epoch 32/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 33/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 34/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 35/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 36/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 37/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9931
# Epoch 38/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 39/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9931
# Epoch 40/100
# 711/711 - 1s - loss: 0.0212 - accuracy: 0.9931
# Epoch 41/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9931
# Epoch 42/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 43/100
# 711/711 - 1s - loss: 0.0211 - accuracy: 0.9931
# Epoch 44/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 45/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 46/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 47/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 48/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 49/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 50/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 51/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 52/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9931
# Epoch 53/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 54/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 55/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 56/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9931
# Epoch 57/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 58/100
# 711/711 - 1s - loss: 0.0210 - accuracy: 0.9931
# Epoch 59/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 60/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 61/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 62/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 63/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 64/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 65/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 66/100
# 711/711 - 1s - loss: 0.0207 - accuracy: 0.9931
# Epoch 67/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 68/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 69/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 70/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 71/100
# 711/711 - 1s - loss: 0.0206 - accuracy: 0.9931
# Epoch 72/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 73/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 74/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 75/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 76/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 77/100
# 711/711 - 1s - loss: 0.0207 - accuracy: 0.9931
# Epoch 78/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 79/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 80/100
# 711/711 - 1s - loss: 0.0207 - accuracy: 0.9931
# Epoch 81/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 82/100
# 711/711 - 0s - loss: 0.0207 - accuracy: 0.9931
# Epoch 83/100
# 711/711 - 1s - loss: 0.0206 - accuracy: 0.9931
# Epoch 84/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 85/100
# 711/711 - 1s - loss: 0.0206 - accuracy: 0.9931
# Epoch 86/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 87/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 88/100
# 711/711 - 1s - loss: 0.0207 - accuracy: 0.9931
# Epoch 89/100
# 711/711 - 1s - loss: 0.0209 - accuracy: 0.9931
# Epoch 90/100
# 711/711 - 1s - loss: 0.0207 - accuracy: 0.9931
# Epoch 91/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 92/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 93/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 94/100
# 711/711 - 1s - loss: 0.0207 - accuracy: 0.9931
# Epoch 95/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 96/100
# 711/711 - 1s - loss: 0.0207 - accuracy: 0.9931
# Epoch 97/100
# 711/711 - 1s - loss: 0.0206 - accuracy: 0.9931
# Epoch 98/100
# 711/711 - 1s - loss: 0.0207 - accuracy: 0.9931
# Epoch 99/100
# 711/711 - 1s - loss: 0.0208 - accuracy: 0.9931
# Epoch 100/100
# 711/711 - 0s - loss: 0.0207 - accuracy: 0.9931

# %%
# model_loss, model_accuracy = model.evaluate(
#     x_test_scaled, y_test_categorical, verbose=2)
# print(
#     f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# model_loss, model_accuracy = deep_model.evaluate(
#     x_test_scaled, y_test_categorical, verbose=2)
# print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
###### the classification part ############
from sklearn.neighbors import KNeighborsClassifier

# %%
features["Burnout"] = 0
features["Burnout"].astype(str)
features.head()
# Out:
#    Month_Joined  Gender  Company_Type  WFH_Setup_Available  Designation  \
# 0             9       1             0                    0          2.0
# 1            11       0             0                    1          1.0
# 2             3       1             1                    1          2.0
# 3            11       0             0                    1          1.0
# 4             7       1             0                    0          3.0
#
#    Resource_Allocation  Mental_Fatigue_Score  Burn_Rate  Burnout
# 0                  3.0                   3.8        0.2        0
# 1                  2.0                   5.0        0.4        0
# 2                  0.0                   5.8        0.5        0
# 3                  1.0                   2.6        0.2        0
# 4                  7.0                   6.9        0.5        0

# %%
features.loc[features.Burn_Rate < "7.0", "Burnout"] = "Chill"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-04eeccd83370> in <module>
# ----> 1 features.loc[features.Burn_Rate < "7.0", "Burnout"] = "Chill"
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     527         rvalues = extract_array(other, extract_numpy=True)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
#     530
#     531         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     254
#     255         if res_values is NotImplemented:
# --> 256             res_values = invalid_comparison(lvalues, rvalues, op)
#     257         if is_scalar(res_values):
#     258             typ = type(rvalues)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\invalid.py in invalid_comparison(left, right, op)
#      32     else:
#      33         typ = type(right).__name__
# ---> 34         raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      35     return res_values
#      36
#
# TypeError: Invalid comparison between dtype=float64 and str

# %%
target = features["Burn_Rate"]
target_names = ["Good", "Burnt Out"]

# %%
# burned = features.drop("Burn_Rate", axis = 1)
# names = burned.columns
# burned.head()

# %%
burned.dtypes

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(burned, target, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

X_scaler = StandardScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
multi_output_clf = MultiOutputRegressor(LinearRegression())
multi_output_clf.fit(variables.values.reshape(-1, 1),results)
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    train_score = knn.score(X_train_scaled, y_train)
    test_score = knn.score(X_test_scaled, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 20, 2), train_scores, marker='o')
plt.plot(range(1, 20, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(X_train_scaled, y_train)
print('k=13 Test Acc: %.3f' % knn.score(X_test_scaled, y_test))
