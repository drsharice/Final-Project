# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import datetime as dt
import matplotlib
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import seaborn as sns
from math import floor, ceil
from pylab import rcParams

# %%
# Training Data Paths
burn = pd.read_csv("burntrain.csv")
burn2 = pd.read_csv("burntest.csv")
burn.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe32003000360033003200      2008-09-30  Female      Service
# 1      fffe3700360033003500      2008-11-30    Male      Service
# 2  fffe31003300320037003900      2008-03-10  Female      Product
# 3  fffe32003400380032003900      2008-11-03    Male      Service
# 4  fffe31003900340031003600      2008-07-24  Female      Service
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score  \
# 0                  No          2.0                  3.0                   3.8
# 1                 Yes          1.0                  2.0                   5.0
# 2                 Yes          2.0                  NaN                   5.8
# 3                 Yes          1.0                  1.0                   2.6
# 4                  No          3.0                  7.0                   6.9
#
#    Burn Rate
# 0       0.16
# 1       0.36
# 2       0.49
# 3       0.20
# 4       0.52

# %%
burn2.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe31003300390039003000      2008-12-10  Female      Service
# 1  fffe31003300310037003800      2008-08-14  Female      Product
# 2  fffe33003400380035003900      2008-11-13    Male      Product
# 3      fffe3100370039003200      2008-02-07  Female      Service
# 4  fffe32003600390036003700      2008-07-17  Female      Product
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score
# 0                  No          2.0                  5.0                   7.7
# 1                 Yes          1.0                  2.0                   5.2
# 2                 Yes          1.0                  3.0                   5.9
# 3                  No          3.0                  6.0                   4.6
# 4                  No          2.0                  5.0                   6.4

# %%
del burn['Employee ID']
del burn2['Employee ID']

# %%
burn = burn.replace(np.nan, 0)
burn2 = burn2.replace(np.nan, 0)
burn.head(5)
# Out:
#   Date of Joining  Gender Company Type WFH Setup Available  Designation  \
# 0      2008-09-30  Female      Service                  No          2.0
# 1      2008-11-30    Male      Service                 Yes          1.0
# 2      2008-03-10  Female      Product                 Yes          2.0
# 3      2008-11-03    Male      Service                 Yes          1.0
# 4      2008-07-24  Female      Service                  No          3.0
#
#    Resource Allocation  Mental Fatigue Score  Burn Rate
# 0                  3.0                   3.8       0.16
# 1                  2.0                   5.0       0.36
# 2                  0.0                   5.8       0.49
# 3                  1.0                   2.6       0.20
# 4                  7.0                   6.9       0.52

# %%
burn['Date of Joining'] =  pd.to_datetime(burn["Date of Joining"])
burn2['Date of Joining'] =  pd.to_datetime(burn2["Date of Joining"])
burn.head()
# Out:
#   Date of Joining  Gender Company Type WFH Setup Available  Designation  \
# 0      2008-09-30  Female      Service                  No          2.0
# 1      2008-11-30    Male      Service                 Yes          1.0
# 2      2008-03-10  Female      Product                 Yes          2.0
# 3      2008-11-03    Male      Service                 Yes          1.0
# 4      2008-07-24  Female      Service                  No          3.0
#
#    Resource Allocation  Mental Fatigue Score  Burn Rate
# 0                  3.0                   3.8       0.16
# 1                  2.0                   5.0       0.36
# 2                  0.0                   5.8       0.49
# 3                  1.0                   2.6       0.20
# 4                  7.0                   6.9       0.52

# %%
burn2.head()
# Out:
#   Date of Joining  Gender Company Type WFH Setup Available  Designation  \
# 0      2008-12-10  Female      Service                  No          2.0
# 1      2008-08-14  Female      Product                 Yes          1.0
# 2      2008-11-13    Male      Product                 Yes          1.0
# 3      2008-02-07  Female      Service                  No          3.0
# 4      2008-07-17  Female      Product                  No          2.0
#
#    Resource Allocation  Mental Fatigue Score
# 0                  5.0                   7.7
# 1                  2.0                   5.2
# 2                  3.0                   5.9
# 3                  6.0                   4.6
# 4                  5.0                   6.4

# %%
burn['Date of Joining'] = pd.DatetimeIndex(burn['Date of Joining']).month
burn.rename(columns = {'Date of Joining' : 'Month Joined'}, inplace = True)
burn2['Date of Joining'] = pd.DatetimeIndex(burn2['Date of Joining']).month
burn2.rename(columns = {'Date of Joining' : 'Month Joined'}, inplace = True)
burn.head(10)
# Out:
#    Month Joined  Gender Company Type WFH Setup Available  Designation  \
# 0             9  Female      Service                  No          2.0
# 1            11    Male      Service                 Yes          1.0
# 2             3  Female      Product                 Yes          2.0
# 3            11    Male      Service                 Yes          1.0
# 4             7  Female      Service                  No          3.0
# 5            11    Male      Product                 Yes          2.0
# 6             1  Female      Service                  No          3.0
# 7            10  Female      Service                 Yes          2.0
# 8            12  Female      Service                  No          3.0
# 9             3  Female      Product                  No          3.0
#
#    Resource Allocation  Mental Fatigue Score  Burn Rate
# 0                  3.0                   3.8       0.16
# 1                  2.0                   5.0       0.36
# 2                  0.0                   5.8       0.49
# 3                  1.0                   2.6       0.20
# 4                  7.0                   6.9       0.52
# 5                  4.0                   3.6       0.29
# 6                  6.0                   7.9       0.62
# 7                  4.0                   4.4       0.33
# 8                  6.0                   0.0       0.56
# 9                  6.0                   0.0       0.67

# %%
burn_df_clean = {"Gender": {"Male": 0, "Female": 1},
                  "Company Type": {"Service" : 0, "Product" : 1},
                    "WFH Setup Available": {"No" : 0, "Yes": 1}}
burn_new_train = burn.replace(burn_df_clean)
burn_new_test = burn2.replace(burn_df_clean)
burn_new_train.head()
# Out:
#    Month Joined  Gender  Company Type  WFH Setup Available  Designation  \
# 0             9       1             0                    0          2.0
# 1            11       0             0                    1          1.0
# 2             3       1             1                    1          2.0
# 3            11       0             0                    1          1.0
# 4             7       1             0                    0          3.0
#
#    Resource Allocation  Mental Fatigue Score  Burn Rate
# 0                  3.0                   3.8       0.16
# 1                  2.0                   5.0       0.36
# 2                  0.0                   5.8       0.49
# 3                  1.0                   2.6       0.20
# 4                  7.0                   6.9       0.52

# %%
burn_new_test.head()
# Out:
#    Month Joined  Gender  Company Type  WFH Setup Available  Designation  \
# 0            12       1             0                    0          2.0
# 1             8       1             1                    1          1.0
# 2            11       0             1                    1          1.0
# 3             2       1             0                    0          3.0
# 4             7       1             1                    0          2.0
#
#    Resource Allocation  Mental Fatigue Score
# 0                  5.0                   7.7
# 1                  2.0                   5.2
# 2                  3.0                   5.9
# 3                  6.0                   4.6
# 4                  5.0                   6.4

# %%
features = pd.get_dummies(burn_new_train)
features.head(5)
# Out:
#    Month Joined  Gender  Company Type  WFH Setup Available  Designation  \
# 0             9       1             0                    0          2.0
# 1            11       0             0                    1          1.0
# 2             3       1             1                    1          2.0
# 3            11       0             0                    1          1.0
# 4             7       1             0                    0          3.0
#
#    Resource Allocation  Mental Fatigue Score  Burn Rate
# 0                  3.0                   3.8       0.16
# 1                  2.0                   5.0       0.36
# 2                  0.0                   5.8       0.49
# 3                  1.0                   2.6       0.20
# 4                  7.0                   6.9       0.52

# %%
features_test = pd.get_dummies(burn_new_test)
features_test.head()
# Out:
#    Month Joined  Gender  Company Type  WFH Setup Available  Designation  \
# 0            12       1             0                    0          2.0
# 1             8       1             1                    1          1.0
# 2            11       0             1                    1          1.0
# 3             2       1             0                    0          3.0
# 4             7       1             1                    0          2.0
#
#    Resource Allocation  Mental Fatigue Score
# 0                  5.0                   7.7
# 1                  2.0                   5.2
# 2                  3.0                   5.9
# 3                  6.0                   4.6
# 4                  5.0                   6.4

# %%
features["Burn Rate"].max()
# Out:
# 1.0

# %%
features.rename(columns = {'Burn Rate' : 'Burn_Rate'}, inplace = True)

# %%
features['Burn_Rate'] = features['Burn_Rate'].round(decimals=1)
features.head()
# Out:
#    Month Joined  Gender  Company Type  WFH Setup Available  Designation  \
# 0             9       1             0                    0          2.0
# 1            11       0             0                    1          1.0
# 2             3       1             1                    1          2.0
# 3            11       0             0                    1          1.0
# 4             7       1             0                    0          3.0
#
#    Resource Allocation  Mental Fatigue Score  Burn_Rate
# 0                  3.0                   3.8        0.2
# 1                  2.0                   5.0        0.4
# 2                  0.0                   5.8        0.5
# 3                  1.0                   2.6        0.2
# 4                  7.0                   6.9        0.5

# %%
features.Burn_Rate.value_counts().plot(kind="bar", rot=0)

# %%
# A general correlations matrix
corr_mat = features.corr() 
fig, ax = plt.subplots(figsize=(20, 12)) 
sns.heatmap(corr_mat, vmax=1.0, square=True, ax=ax);

# %%
features.columns = features.columns.str.replace(' ', '_')
features.head()
# Out:
#    Month_Joined  Gender  Company_Type  WFH_Setup_Available  Designation  \
# 0             9       1             0                    0          2.0
# 1            11       0             0                    1          1.0
# 2             3       1             1                    1          2.0
# 3            11       0             0                    1          1.0
# 4             7       1             0                    0          3.0
#
#    Resource_Allocation  Mental_Fatigue_Score  Burn_Rate
# 0                  3.0                   3.8        0.2
# 1                  2.0                   5.0        0.4
# 2                  0.0                   5.8        0.5
# 3                  1.0                   2.6        0.2
# 4                  7.0                   6.9        0.5

# %%
features_test.head()
# Out:
#    Month Joined  Gender  Company Type  WFH Setup Available  Designation  \
# 0            12       1             0                    0          2.0
# 1             8       1             1                    1          1.0
# 2            11       0             1                    1          1.0
# 3             2       1             0                    0          3.0
# 4             7       1             1                    0          2.0
#
#    Resource Allocation  Mental Fatigue Score
# 0                  5.0                   7.7
# 1                  2.0                   5.2
# 2                  3.0                   5.9
# 3                  6.0                   4.6
# 4                  5.0                   6.4

# %%
X = features['Gender'].values
Y = features['Burn_Rate'].values

# %%
plt.scatter(X, Y, c='red', label='Scatter Plot')
plt.xlabel('Gender')
plt.ylabel('An individuals burn rate')
plt.legend()
plt.show()

# %%
x_train = features[["Designation",  "Resource_Allocation"]].values
y_train = features["Burn_Rate"].values
x_test = features_test[["Designation",  "Resource Allocation"]].values
y_test = features_test["Gender"].values

# %%
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical
x_scaler = StandardScaler().fit(x_train)
x_train_scaled = x_scaler.transform(x_train)
x_test_scaled = x_scaler.transform(x_test)
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
from tensorflow.keras.models import Sequential

model = Sequential()

# %%
from tensorflow.keras.layers import Dense
number_inputs = 2
number_hidden_nodes = 4
model.add(Dense(units=number_hidden_nodes,
                activation='relu', input_dim=number_inputs))

# %%
number_classes = 2
model.add(Dense(units=number_classes, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 4)                 12
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 10
# =================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fit (train) the model
model.fit(
    x_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 711/711 - 1s - loss: 0.2787 - accuracy: 0.9374
# Epoch 2/100
# 711/711 - 0s - loss: 0.0542 - accuracy: 0.9931
# Epoch 3/100
# 711/711 - 0s - loss: 0.0398 - accuracy: 0.9931
# Epoch 4/100
# 711/711 - 0s - loss: 0.0323 - accuracy: 0.9931
# Epoch 5/100
# 711/711 - 0s - loss: 0.0287 - accuracy: 0.9931
# Epoch 6/100
# 711/711 - 0s - loss: 0.0268 - accuracy: 0.9931
# Epoch 7/100
# 711/711 - 0s - loss: 0.0264 - accuracy: 0.9931
# Epoch 8/100
# 711/711 - 0s - loss: 0.0263 - accuracy: 0.9931
# Epoch 9/100
# 711/711 - 0s - loss: 0.0261 - accuracy: 0.9931
# Epoch 10/100
# 711/711 - 0s - loss: 0.0259 - accuracy: 0.9931
# Epoch 11/100
# 711/711 - 0s - loss: 0.0259 - accuracy: 0.9931
# Epoch 12/100
# 711/711 - 0s - loss: 0.0257 - accuracy: 0.9931
# Epoch 13/100
# 711/711 - 0s - loss: 0.0256 - accuracy: 0.9931
# Epoch 14/100
# 711/711 - 0s - loss: 0.0256 - accuracy: 0.9931
# Epoch 15/100
# 711/711 - 0s - loss: 0.0254 - accuracy: 0.9931
# Epoch 16/100
# 711/711 - 0s - loss: 0.0253 - accuracy: 0.9931
# Epoch 17/100
# 711/711 - 0s - loss: 0.0251 - accuracy: 0.9931
# Epoch 18/100
# 711/711 - 0s - loss: 0.0249 - accuracy: 0.9931
# Epoch 19/100
# 711/711 - 0s - loss: 0.0250 - accuracy: 0.9931
# Epoch 20/100
# 711/711 - 0s - loss: 0.0249 - accuracy: 0.9931
# Epoch 21/100
# 711/711 - 0s - loss: 0.0247 - accuracy: 0.9931
# Epoch 22/100
# 711/711 - 0s - loss: 0.0246 - accuracy: 0.9931
# Epoch 23/100
# 711/711 - 0s - loss: 0.0244 - accuracy: 0.9931
# Epoch 24/100
# 711/711 - 0s - loss: 0.0243 - accuracy: 0.9931
# Epoch 25/100
# 711/711 - 0s - loss: 0.0242 - accuracy: 0.9931
# Epoch 26/100
# 711/711 - 0s - loss: 0.0241 - accuracy: 0.9931
# Epoch 27/100
# 711/711 - 0s - loss: 0.0240 - accuracy: 0.9931
# Epoch 28/100
# 711/711 - 0s - loss: 0.0239 - accuracy: 0.9931
# Epoch 29/100
# 711/711 - 0s - loss: 0.0237 - accuracy: 0.9931
# Epoch 30/100
# 711/711 - 0s - loss: 0.0237 - accuracy: 0.9931
# Epoch 31/100
# 711/711 - 0s - loss: 0.0235 - accuracy: 0.9931
# Epoch 32/100
# 711/711 - 0s - loss: 0.0235 - accuracy: 0.9931
# Epoch 33/100
# 711/711 - 0s - loss: 0.0233 - accuracy: 0.9931
# Epoch 34/100
# 711/711 - 0s - loss: 0.0232 - accuracy: 0.9931
# Epoch 35/100
# 711/711 - 0s - loss: 0.0232 - accuracy: 0.9931
# Epoch 36/100
# 711/711 - 0s - loss: 0.0230 - accuracy: 0.9931
# Epoch 37/100
# 711/711 - 0s - loss: 0.0230 - accuracy: 0.9931
# Epoch 38/100
# 711/711 - 0s - loss: 0.0228 - accuracy: 0.9931
# Epoch 39/100
# 711/711 - 0s - loss: 0.0228 - accuracy: 0.9931
# Epoch 40/100
# 711/711 - 0s - loss: 0.0227 - accuracy: 0.9931
# Epoch 41/100
# 711/711 - 0s - loss: 0.0226 - accuracy: 0.9931
# Epoch 42/100
# 711/711 - 0s - loss: 0.0224 - accuracy: 0.9931
# Epoch 43/100
# 711/711 - 0s - loss: 0.0224 - accuracy: 0.9931
# Epoch 44/100
# 711/711 - 0s - loss: 0.0223 - accuracy: 0.9931
# Epoch 45/100
# 711/711 - 0s - loss: 0.0223 - accuracy: 0.9931
# Epoch 46/100
# 711/711 - 0s - loss: 0.0222 - accuracy: 0.9931
# Epoch 47/100
# 711/711 - 0s - loss: 0.0221 - accuracy: 0.9931
# Epoch 48/100
# 711/711 - 0s - loss: 0.0221 - accuracy: 0.9931
# Epoch 49/100
# 711/711 - 0s - loss: 0.0219 - accuracy: 0.9930
# Epoch 50/100
# 711/711 - 0s - loss: 0.0219 - accuracy: 0.9931
# Epoch 51/100
# 711/711 - 0s - loss: 0.0219 - accuracy: 0.9931
# Epoch 52/100
# 711/711 - 0s - loss: 0.0219 - accuracy: 0.9931
# Epoch 53/100
# 711/711 - 0s - loss: 0.0219 - accuracy: 0.9930
# Epoch 54/100
# 711/711 - 0s - loss: 0.0218 - accuracy: 0.9931
# Epoch 55/100
# 711/711 - 0s - loss: 0.0217 - accuracy: 0.9930
# Epoch 56/100
# 711/711 - 0s - loss: 0.0217 - accuracy: 0.9930
# Epoch 57/100
# 711/711 - 0s - loss: 0.0216 - accuracy: 0.9930
# Epoch 58/100
# 711/711 - 0s - loss: 0.0216 - accuracy: 0.9930
# Epoch 59/100
# 711/711 - 0s - loss: 0.0215 - accuracy: 0.9932
# Epoch 60/100
# 711/711 - 0s - loss: 0.0216 - accuracy: 0.9930
# Epoch 61/100
# 711/711 - 0s - loss: 0.0216 - accuracy: 0.9929
# Epoch 62/100
# 711/711 - 0s - loss: 0.0215 - accuracy: 0.9928
# Epoch 63/100
# 711/711 - 0s - loss: 0.0215 - accuracy: 0.9930
# Epoch 64/100
# 711/711 - 0s - loss: 0.0214 - accuracy: 0.9930
# Epoch 65/100
# 711/711 - 0s - loss: 0.0214 - accuracy: 0.9930
# Epoch 66/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9932
# Epoch 67/100
# 711/711 - 0s - loss: 0.0214 - accuracy: 0.9930
# Epoch 68/100
# 711/711 - 0s - loss: 0.0214 - accuracy: 0.9931
# Epoch 69/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9930
# Epoch 70/100
# 711/711 - 0s - loss: 0.0214 - accuracy: 0.9931
# Epoch 71/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9931
# Epoch 72/100
# 711/711 - 0s - loss: 0.0213 - accuracy: 0.9930
# Epoch 73/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9929
# Epoch 74/100
# 711/711 - 0s - loss: 0.0213 - accuracy: 0.9930
# Epoch 75/100
# 711/711 - 0s - loss: 0.0213 - accuracy: 0.9928
# Epoch 76/100
# 711/711 - 0s - loss: 0.0213 - accuracy: 0.9928
# Epoch 77/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9928
# Epoch 78/100
# 711/711 - 0s - loss: 0.0213 - accuracy: 0.9928
# Epoch 79/100
# 711/711 - 0s - loss: 0.0213 - accuracy: 0.9932
# Epoch 80/100
# 711/711 - 0s - loss: 0.0213 - accuracy: 0.9930
# Epoch 81/100
# 711/711 - 0s - loss: 0.0213 - accuracy: 0.9930
# Epoch 82/100
# 711/711 - 0s - loss: 0.0213 - accuracy: 0.9931
# Epoch 83/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9930
# Epoch 84/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9930
# Epoch 85/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 86/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9932
# Epoch 87/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9931
# Epoch 88/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9930
# Epoch 89/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9931
# Epoch 90/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9928
# Epoch 91/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 92/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9930
# Epoch 93/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9928
# Epoch 94/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9931
# Epoch 95/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9931
# Epoch 96/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9931
# Epoch 97/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9931
# Epoch 98/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9929
# Epoch 99/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9930
# Epoch 100/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9929

# %%
model_loss, model_accuracy = model.evaluate(
    x_test_scaled, y_test_categorical, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 383/383 - 0s - loss: 4.4041 - accuracy: 0.4738
# Loss: 4.4041361808776855, Accuracy: 0.47379592061042786

# %%
#round 2
deep_model = Sequential()
deep_model.add(Dense(units=6, activation='relu', input_dim=2))
deep_model.add(Dense(units=6, activation='relu'))
deep_model.add(Dense(units=2, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 6)                 18
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 14
# =================================================================
# Total params: 74
# Trainable params: 74
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    x_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 711/711 - 1s - loss: 0.1420 - accuracy: 0.9931
# Epoch 2/100
# 711/711 - 0s - loss: 0.0393 - accuracy: 0.9931
# Epoch 3/100
# 711/711 - 0s - loss: 0.0315 - accuracy: 0.9931
# Epoch 4/100
# 711/711 - 0s - loss: 0.0290 - accuracy: 0.9931
# Epoch 5/100
# 711/711 - 0s - loss: 0.0278 - accuracy: 0.9931
# Epoch 6/100
# 711/711 - 0s - loss: 0.0269 - accuracy: 0.9931
# Epoch 7/100
# 711/711 - 0s - loss: 0.0259 - accuracy: 0.9931
# Epoch 8/100
# 711/711 - 0s - loss: 0.0247 - accuracy: 0.9931
# Epoch 9/100
# 711/711 - 0s - loss: 0.0238 - accuracy: 0.9931
# Epoch 10/100
# 711/711 - 0s - loss: 0.0229 - accuracy: 0.9931
# Epoch 11/100
# 711/711 - 0s - loss: 0.0222 - accuracy: 0.9931
# Epoch 12/100
# 711/711 - 0s - loss: 0.0217 - accuracy: 0.9931
# Epoch 13/100
# 711/711 - 0s - loss: 0.0215 - accuracy: 0.9931
# Epoch 14/100
# 711/711 - 0s - loss: 0.0213 - accuracy: 0.9931
# Epoch 15/100
# 711/711 - 0s - loss: 0.0212 - accuracy: 0.9931
# Epoch 16/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9931
# Epoch 17/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 18/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 19/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9931
# Epoch 20/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 21/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 22/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9931
# Epoch 23/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 24/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 25/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 26/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 27/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 28/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9931
# Epoch 29/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 30/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9931
# Epoch 31/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 32/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 33/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 34/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9931
# Epoch 35/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 36/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 37/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 38/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 39/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 40/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 41/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 42/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 43/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 44/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 45/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 46/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 47/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 48/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 49/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 50/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 51/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 52/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 53/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 54/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 55/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 56/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 57/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 58/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 59/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 60/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 61/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 62/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 63/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 64/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 65/100
# 711/711 - 0s - loss: 0.0211 - accuracy: 0.9931
# Epoch 66/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 67/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 68/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 69/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 70/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 71/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 72/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 73/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 74/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 75/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 76/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 77/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 78/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 79/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 80/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 81/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 82/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 83/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 84/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 85/100
# 711/711 - 0s - loss: 0.0210 - accuracy: 0.9931
# Epoch 86/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 87/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 88/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 89/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 90/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 91/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 92/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 93/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 94/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 95/100
# 711/711 - 0s - loss: 0.0207 - accuracy: 0.9931
# Epoch 96/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931
# Epoch 97/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 98/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 99/100
# 711/711 - 0s - loss: 0.0208 - accuracy: 0.9931
# Epoch 100/100
# 711/711 - 0s - loss: 0.0209 - accuracy: 0.9931

# %%
model_loss, model_accuracy = model.evaluate(
    x_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
model_loss, model_accuracy = deep_model.evaluate(
    x_test_scaled, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
y_train_categorical.shape
# Out:
# (22750, 11)
